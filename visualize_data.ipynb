# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
train_df_100 = pd.read_csv(f'experiments/cnn_distill/resnet18_train_log.csv')
test_df_100 = pd.read_csv(f'experiments/cnn_distill/resnet18_test_log.csv')
train_df_50 = pd.read_csv(f'experiments/cnn_distill_subset/train_log_0.5.csv')
test_df_50 = pd.read_csv(f'experiments/cnn_distill_subset/test_log_0.5.csv')
train_df_20 = pd.read_csv(f'experiments/cnn_distill_subset/train_log_0.2.csv')
test_df_20 = pd.read_csv(f'experiments/cnn_distill_subset/test_log_0.2.csv')
train_df_10 = pd.read_csv(f'experiments/cnn_distill_subset/train_log_0.1.csv')
test_df_10 = pd.read_csv(f'experiments/cnn_distill_subset/test_log_0.1.csv')
train_df_5 = pd.read_csv(f'experiments/cnn_distill_subset/train_log_0.05.csv')
test_df_5 = pd.read_csv(f'experiments/cnn_distill_subset/test_log_0.05.csv')

# %%
x = np.arange(100)

plt.plot(x, test_df_100['val_acc'], label='Acc 100% dataset')
plt.plot(x, test_df_50['val_acc'], label='Acc 50% dataset')
plt.plot(x, test_df_20['val_acc'], label='Acc 20% dataset')
plt.plot(x, test_df_10['val_acc'], label='Acc 10% dataset')
plt.plot(x, test_df_5['val_acc'], label='Acc 5% dataset')
plt.legend()
plt.show()
